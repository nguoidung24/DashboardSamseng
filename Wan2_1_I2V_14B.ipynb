# %% [markdown]
# **PREPARE ENVIRONMENT**

# %% [markdown]
# - You can set **parameters_in_vram** to 10 or less to reduce the VRAM used, especially if you want to generate a video with a resolution greater than 480 by 832 or 832 by 480. The VRAM used depends on the value of **parameters_in_vram** and the resolutions of the input image & output video.
# - Setting **parameters_in_vram** to 15 with a video resolution of 480 by 832 will result in a generation time of approximately 10 minutes. Lower values of **parameters_in_vram** will result in longer generation times. Higher values can reduce the video generation time, but increase the risk of getting **Out of Memory Error**s.

# %%
# @title
# !git clone https://github.com/Isi-dev/DiffSynth-Studio.git
# %cd DiffSynth-Studio
# !pip install -e .
# !pip install "huggingface_hub[cli]"
# !apt-get install -y aria2
import os
from huggingface_hub import list_repo_files

repo_id = "Isi99999/Wan2.1-I2V-14B-480P"
all_files = list_repo_files(repo_id)
base_url = f"https://huggingface.co/{repo_id}/resolve/main/"

with open("file_list.txt", "w") as f:
    for file_path in all_files:
        full_url = f"{base_url}{file_path}"
        save_path = f"models/Wan-AI/Wan2.1-I2V-14B-480P/{file_path}"
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        f.write(f"{full_url}\n out={save_path}\n")
# !aria2c -x 16 -s 16 -i file_list.txt --continue=true --auto-file-renaming=false

print("✅ All models downloaded successfully!")

import torch
from diffsynth import ModelManager, WanVideoPipeline, VideoData, save_video

model_manager = ModelManager(device="cuda")
model_manager.load_models(
    ["models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth"],
    torch_dtype=torch.float16, # Image Encoder is loaded with float16
)
model_manager.load_models(
    [
        "models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors",
        "models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors",
        "models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors",
    ],
    torch_dtype=torch.torch.bfloat16, # You can set `torch_dtype=torch.float8_e4m3fn` or `torch_dtype=torch.bfloat16` to disable FP8 quantization.
)

pipe = WanVideoPipeline.from_model_manager(model_manager, torch_dtype=torch.bfloat16, device="cuda")
parameters_in_vram = 12 # @param {"type":"number"}
pipe.enable_vram_management(num_persistent_param_in_dit=parameters_in_vram*10**9) # You can set `num_persistent_param_in_dit` to a small number to reduce VRAM required.
print("✅ All models loaded successfully!")
# Out:
# fatal: destination path 'DiffSynth-Studio' already exists and is not an empty directory.
# /content/DiffSynth-Studio
# Obtaining file:///content/DiffSynth-Studio
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.21.0+cu124)
# Requirement already satisfied: cupy-cuda12x in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (13.3.0)
# Requirement already satisfied: transformers==4.46.2 in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (4.46.2)
# Requirement already satisfied: controlnet-aux==0.0.7 in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.0.7)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (2.37.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.5.3)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (5.29.4)
# Requirement already satisfied: modelscope in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (1.24.1)
# Requirement already satisfied: ftfy in /usr/local/lib/python3.11/dist-packages (from diffsynth==1.1.2) (6.3.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (8.6.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (0.29.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (1.14.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (4.11.0.86)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (3.18.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (11.1.0)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (1.0.15)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from controlnet-aux==0.0.7->diffsynth==1.1.2) (0.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (0.20.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers==4.46.2->diffsynth==1.1.2) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->diffsynth==1.1.2) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->diffsynth==1.1.2) (1.3.0)
# Requirement already satisfied: fastrlock>=0.5 in /usr/local/lib/python3.11/dist-packages (from cupy-cuda12x->diffsynth==1.1.2) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from ftfy->diffsynth==1.1.2) (0.2.13)
# Requirement already satisfied: imageio-ffmpeg in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]->diffsynth==1.1.2) (0.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from imageio[ffmpeg]->diffsynth==1.1.2) (5.9.5)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.11/dist-packages (from modelscope->diffsynth==1.1.2) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.2->diffsynth==1.1.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.2->diffsynth==1.1.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers==4.46.2->diffsynth==1.1.2) (2025.1.31)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->controlnet-aux==0.0.7->diffsynth==1.1.2) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->diffsynth==1.1.2) (3.0.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->controlnet-aux==0.0.7->diffsynth==1.1.2) (2025.3.13)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->controlnet-aux==0.0.7->diffsynth==1.1.2) (0.4)
# Installing collected packages: diffsynth
#   Attempting uninstall: diffsynth
#     Found existing installation: diffsynth 1.1.2
#     Uninstalling diffsynth-1.1.2:
#       Successfully uninstalled diffsynth-1.1.2
#   Running setup.py develop for diffsynth
# Successfully installed diffsynth-1.1.2
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.11/dist-packages (0.29.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (4.12.2)
# Requirement already satisfied: InquirerPy==0.3.4 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: pfzy<0.4.0,>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (0.3.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.50)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub[cli]) (2025.1.31)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# aria2 is already the newest version (1.36.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# 03/30 07:15:41 [NOTICE] Downloading 15 item(s)
#
# 03/30 07:15:41 [NOTICE] CUID#9 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/1ab9a32cc2c740f6e39d80d367ce5dcc28db8c71b79b28670546b8973e9d75f9?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27Wan2.1_VAE.safetensors%3B+filename%3D%22Wan2.1_VAE.safetensors%22%3B&Expires=1743321335&Policy=&Signature=a1zl6KGCXbp-1CVmr8eU%7E5sOBV-cV4Gt6pC5RNgEw0fqfSJJ687Yzv8FZqfx3d0U4MHYSPo-KzWW139kq4oiQRI1TPlB4%7ETxTP9jvbqy67Lq%7E6Rujdjyo04ibN7yYzm8ky3mg1QL75CGS6K9k2F2SCfiAMf90Ol81j7viBNHhyD4wHx9p1Wi5Eu-tSiPZy9wy-ij5M1CukG57HgTq4fj45GTyKc31BvikHQ86ig-rEY9uI7HGxTA2TeowxM6jYpK3CXHqyEhwhflXFB-q67EBMJumDVh7n%7EDB3t2xF8Vbyz6ml9hElM5Hh7iGAGUaJR20FLL9BcolvUAsvXaTYE6hQ__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] CUID#11 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/996dbad030df09b0b3c8e764f0fb5a81b98b220ab89524d6a9369e9ed882791f?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27diffusion_pytorch_model.safetensors%3B+filename%3D%22diffusion_pytorch_model.safetensors%22%3B&Expires=1743322541&Policy=&Signature=GnvzOlhFPkskYPdph6BngLjN0uayNC4HElMgMuin0hktHcjyMm5quqQ3vuwlsh6wBgUbzz4ybokOO6WbGjijLIdAauLyn5gn7nyoZgBnvSQCau1gkY5XI-o4kyYCp-ZDngXDVaF4jtS2Xq12yWTjNt5RtglBJkKDamTcMhl8Xutf9WElEhQ3AhA4WmiIfdJj6uAW7jjmK605nmnH89Wc65QF2COvBgRQ3pkwpZgnIsAuw45w5VJfX7NxiRja6dTLale-YRZcSCIcos2dXKGf-kw51wvBqfB3GRwaujJSECftqOx9o8XtzR00-NQwKC-FcG4qPTlXH8LsZCJc1Ryq%7Eg__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] GID#2c7803f63ce7b22b - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/config.json
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/config.json
#
# 03/30 07:15:41 [NOTICE] GID#60e830f7931c533d - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/README.md
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/README.md
#
# 03/30 07:15:41 [NOTICE] GID#56807257cf491af9 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
#
# 03/30 07:15:41 [NOTICE] GID#1d6a5e671630c707 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/special_tokens_map.json
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/special_tokens_map.json
#
# 03/30 07:15:41 [NOTICE] CUID#13 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/e3909a67b780650b35cf529ac782ad2b6b26e6d1f849d3fbb6a872905f452458?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27spiece.model%3B+filename%3D%22spiece.model%22%3B&Expires=1743322541&Policy=&Signature=YP29dvnJ7i%7ES3ctMQUYDdnIfCj%7EtCzweCNxqSyIX9UOLB9MrHm6Q1tIuhFAfnf8CCFIEmnv8qItVc6xULb5IBzdiIQbJDEsYvy5kaQmfzWtAxOf10ZLi9citA2WaF7nQbeTMzY1KZbVbeGemUysCzqRRWEcYyE3%7EfA5W%7Epvkil5hYOX4ek-QpoFf8W4PCHpupqgyGKQ5F6nZ8t%7EnA7sjUca9toaeu85Zp5mpzer12dlzH0ahYmkaD6ogj-x8GnKG6MVAdlS%7EO8RhsvbsuC%7EF9ePplpsSzN2Xoupiu-Dg-WdhAmRPCOIjALjhSTN%7EVStoQCKPgFLHpJE3wW9%7E7l9jkQ__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] GID#e4a7474f8ac4330f - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors
#
# 03/30 07:15:41 [NOTICE] CUID#14 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/6e197b4d3dbd71da14b4eb255f4fa91c9c1f2068b20a2de2472967ca3d22602b?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27tokenizer.json%3B+filename%3D%22tokenizer.json%22%3B&response-content-type=application%2Fjson&Expires=1743322541&Policy=...&Signature=TDqzyzpXknF3LODNarkMHSX0F%7EZvXjqTq1xH-iZZaqDuDJ92Q8zEYpCvVHIEcSk2aPVPuWuW0QFV6EVgOk%7EXCd4iZJIGImkWo2jVQKFfzzXUxgvLannY3BbwyoVDQMQ6UM5ixWF%7EXC0r2wZV2NFLoFfOiMKjW6lNuHSaixUfySlD9422foDgNRcJID7chJCvcxyCefwz17p1kianAUPFxe4LpiKQ4wj4IeKMaz96rWydpoMhpWsmVO2MIjhIfgUqozoPS17eBg74cRLuH834NGxnVnl2hCsRnNYa8o6EzKPCQyKLiuSKDSRBEhUgzbxc-iuvZcMwTHbBwL3-m9AD0w__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] GID#3d25ec7d4abeafe9 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/spiece.model
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/spiece.model
#
# 03/30 07:15:41 [NOTICE] GID#3909dece3a3adfa1 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer.json
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer.json
#
# 03/30 07:15:41 [NOTICE] CUID#16 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/628c9998b613391f193eb67ff68da9667d75f492911e4eb3decf23460a158c38?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth%3B+filename%3D%22models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth%22%3B&Expires=1743322541&Policy=&Signature=O4NxsUoVHyRTc%7ES0OivoN5K5aeSYUWFTBjpG2UqsW5G5v77eOTQtwK0NoIB-p1zCDK81LK-JiRfEWtzvcczAOq5cZDjSnX1rdX42xRMy9XoGngZ1E1dE-o0a88%7Eak-b1ZVnxWZQ0Co3gAL9R6Clyd2Z723CWjIyjJPKt%7EeLX8UQEWypuoTQm0cvbCZnnveH8n3nPThYJz22xQyl1ycJcakzL5Q97mfk4xmJ9-7BWXR3Wh%7Enj4bTwLI6eFmFOQspZ2B-kKoukXbL6fmO3vSzEmVVHBgKKyPN3N1ejlfB2dVbSQMiEz91kK5vwVWWnrr6SaaWlEMNzK9Qpy6BqzBfypA__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] GID#8421325af05a8b60 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer_config.json
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer_config.json
#
# 03/30 07:15:41 [NOTICE] CUID#17 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/3fe5173588270c22505d4f9158bb1644b78331b8614206a97e92760b960c9ffa?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27models_t5_umt5-xxl-enc-bf16.safetensors%3B+filename%3D%22models_t5_umt5-xxl-enc-bf16.safetensors%22%3B&Expires=1743322541&Policy=&Signature=Khxp7Ld89oV4d5I1xHiDxNWsaFfUK6rj90rj5GNDyTDVr1C6Hr9zM2UReW%7ESJ3H4Li4gd5LjTbctzZvLzUD4e6epawZcI3Fy2xNu8byfSRfjsPT4zkZmB52xjR7L-wnjmAnNBWHBP14f2JKjNvRq3zdk8pY0cy9zHHBdinTZqhqEM5eaS3rFRO%7EwhI1ZFxY-PGt9fwce3kj-8SIlukxZGuWzkBCaT9ZS416KDzYEbx-U3bhsZJIThukS9LUffYkDy2p%7EPFIOpv4LexpYk6bh0aTqKv0I7vD483VxnKoWo8r70S-hlPvQpfP3c13bALLqM4NRvYLg8tPLzI-gz0a6bQ__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] GID#7c1fc4b86143bc94 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
#
# 03/30 07:15:41 [NOTICE] CUID#18 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/cfc8146abe2a0488e9e2a0c56de7952f7c11ab059eca145a0a727afce0db2865?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27sentencepiece.bpe.model%3B+filename%3D%22sentencepiece.bpe.model%22%3B&Expires=1743322541&Policy=&Signature=E66ts7ok8acEzYB8tgNbX8y5BLPmtHPvAR4C959onpsOQhreisW-lFqeM8UHzBjkg%7ErvLn2s%7EBRz6NiS7qGi0LWdix-s8A1swf2Qlp5ZEYU3XGL%7EtECzDgHG6xp9ayM0PaZ76GFUE4IDHU%7Er7Ku-wc%7ElyaeWUrFY6UVAqQp51qsPwoRn9x%7EljDCFOnYDyTIuAqg-TaPJ%7E0OKNumPL2afqb8D8QOVcR%7Etde5viNyfc4ZYHQEk2cT8QfvWxardYwBh5JC3ByuXWfwf3g2nc0ekcBbliC%7E%7Ehznhb44cHtSI9Pulx6FbRzmh55%7Er7zN08BdGIGWsdTqEOGMIb5k5P%7E4i5Q__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:41 [NOTICE] GID#639983e7e8c13131 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
#
# 03/30 07:15:41 [NOTICE] GID#b8916e20e8eb8e21 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/sentencepiece.bpe.model
#
# 03/30 07:15:41 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/sentencepiece.bpe.model
#
# 03/30 07:15:42 [NOTICE] CUID#20 - Redirecting to https://cdn-lfs-us-1.hf.co/repos/0c/33/0c337ffd39bf0fd5ff0f11ab3b8547ee3a08339a52fa73136e0b5184a6a04347/62c24cdc13d4c9952d63718d6c9fa4c287974249e16b7ade6d5a85e7bbb75626?response-content-disposition=inline%3B+filename*%3DUTF-8%27%27tokenizer.json%3B+filename%3D%22tokenizer.json%22%3B&response-content-type=application%2Fjson&Expires=1743322541&Policy=...&Signature=l6I4SfwzI-4o2a6-wpeFlhiHcEQTnPeK6W7iJAoYWMc%7ELcTwOKUGklYNE3hh1jShZw95YFRI-DNHEQvIjidE10tA-ATCQOtzTvAHe7G3xklEu7yIl7jPyWddp4jot3z1cw4AN3qwupmdf11spdCpzfzOg-GknK6LPxuvnOWzljNbdbZqCYMZzcD52WII6PwauTaaC5xjxTVdj1A2JxbKQdY0NNW3G-ohN8Jw-CKcq5BrjeUX5soEte-H8LSpeZZNz8e3xt35BmerJqtGiOKDUGwDayC7jgeYoVpu7FZ5ET0PMdJu1yaDbLwPNNWrBi6QgoF%7EaO-m1O21yIigDnTjrg__&Key-Pair-Id=K24J24Z295AEI9
#
# 03/30 07:15:42 [NOTICE] GID#ed5eec97841b2308 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/.gitattributes
#
# 03/30 07:15:42 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/.gitattributes
#
# 03/30 07:15:42 [NOTICE] GID#0c89f777d302a4db - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer.json
#
# 03/30 07:15:42 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer.json
#
# 03/30 07:15:42 [NOTICE] GID#47aec3eb8e912f2d - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer_config.json
#
# 03/30 07:15:42 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer_config.json
#
# 03/30 07:15:42 [NOTICE] GID#f0e99cf8b7d0b598 - Download has already completed: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/special_tokens_map.json
#
# 03/30 07:15:42 [NOTICE] Download complete: /content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/special_tokens_map.json
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2c7803|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/config.json
# 60e830|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/README.md
# 568072|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/diffusion_pytorch_model.safetensors
# 1d6a5e|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/special_tokens_map.json
# e4a747|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/Wan2.1_VAE.safetensors
# 3d25ec|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/spiece.model
# 3909de|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer.json
# 842132|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/google/umt5-xxl/tokenizer_config.json
# 7c1fc4|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
# 639983|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/models_t5_umt5-xxl-enc-bf16.safetensors
# b8916e|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/sentencepiece.bpe.model
# ed5eec|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/.gitattributes
# 0c89f7|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer.json
# 47aec3|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/tokenizer_config.json
# f0e99c|OK  |       0B/s|/content/DiffSynth-Studio/models/Wan-AI/Wan2.1-I2V-14B-480P/xlm-roberta-large/special_tokens_map.json
#
# Status Legend:
# (OK):download completed.
# ✅ All models downloaded successfully!
# Loading models from: models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth
#     model_name: wan_video_image_encoder model_class: WanImageEncoder
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-3d850c899933> in <cell line: 0>()
#      26
#      27 model_manager = ModelManager(device="gpu")
# ---> 28 model_manager.load_models(
#      29     ["models/Wan-AI/Wan2.1-I2V-14B-480P/models_clip_open-clip-xlm-roberta-large-vit-huge-14.pth"],
#      30     torch_dtype=torch.float16, # Image Encoder is loaded with float16
#
# /content/DiffSynth-Studio/diffsynth/models/model_manager.py in load_models(self, file_path_list, model_names, device, torch_dtype)
#     420     def load_models(self, file_path_list, model_names=None, device=None, torch_dtype=None):
#     421         for file_path in file_path_list:
# --> 422             self.load_model(file_path, model_names, device=device, torch_dtype=torch_dtype)
#     423
#     424
#
# /content/DiffSynth-Studio/diffsynth/models/model_manager.py in load_model(self, file_path, model_names, device, torch_dtype)
#     403         for model_detector in self.model_detector:
#     404             if model_detector.match(file_path, state_dict):
# --> 405                 model_names, models = model_detector.load(
#     406                     file_path, state_dict,
#     407                     device=device, torch_dtype=torch_dtype,
#
# /content/DiffSynth-Studio/diffsynth/models/model_manager.py in load(self, file_path, state_dict, device, torch_dtype, **kwargs)
#     182         if keys_hash_with_shape in self.keys_hash_with_shape_dict:
#     183             model_names, model_classes, model_resource = self.keys_hash_with_shape_dict[keys_hash_with_shape]
# --> 184             loaded_model_names, loaded_models = load_model_from_single_file(state_dict, model_names, model_classes, model_resource, torch_dtype, device)
#     185             return loaded_model_names, loaded_models
#     186
#
# /content/DiffSynth-Studio/diffsynth/models/model_manager.py in load_model_from_single_file(state_dict, model_names, model_classes, model_resource, torch_dtype, device)
#      74             model = model.eval()
#      75         model.load_state_dict(model_state_dict, assign=True)
# ---> 76         model = model.to(dtype=torch_dtype, device=device)
#      77         loaded_model_names.append(model_name)
#      78         loaded_models.append(model)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in to(self, *args, **kwargs)
#    1300
#    1301         """
# -> 1302         device, dtype, non_blocking, convert_to_format = torch._C._nn._parse_to(
#    1303             *args, **kwargs
#    1304         )
#
# RuntimeError: Expected one of cpu, cuda, ipu, xpu, mkldnn, opengl, opencl, ideep, hip, ve, fpga, maia, xla, lazy, vulkan, mps, meta, hpu, mtia, privateuseone device type at start of device string: gpu

# %% [markdown]
# **RUN TO UPLOAD IMAGE**

# %%
# @title
from google.colab import files
from PIL import Image

uploaded = files.upload()
image_path = list(uploaded.keys())[0]
image = Image.open(image_path)

print("✅Image loaded successfully:", image.size)

# %% [markdown]
# **RUN IMAGE TO VIDEO**

# %%
prompt = "The lady smiles and waves at the camera." # @param {type:"string"}
sample_steps = 30 # @param {"type":"number"}
Instruction = "choose from '720*1280', '1280*720', '480*832', '832*480', '1024*1024 for output video's width & height." # @param {"type":"string"}
width = 480 # @param {"type":"number"}
height = 832 # @param {"type":"number"}
num_frames = 81 # @param {"type":"number"}
seed = 1 # @param {"type":"number"}

# Generate video from text prompt and Image
video = pipe(
    prompt=prompt,
    negative_prompt="色调艳丽，过曝，静态，细节模糊不清，字幕，风格，作品，画作，画面，静止，整体发灰，最差质量，低质量，JPEG压缩残留，丑陋的，残缺的，多余的手指，画得不好的手部，画得不好的脸部，畸形的，毁容的，形态畸形的肢体，手指融合，静止不动的画面，杂乱的背景，三条腿，背景人很多，倒着走",
    input_image=image,
    height = height,
    width = width,
    num_frames=num_frames,
    num_inference_steps=sample_steps,
    seed=seed, tiled=True
)

# # Save the generated video
save_video(video, "video.mp4", fps=15, quality=5)

from IPython.display import display as displayVid, Video as outVid
import os

# Function to display video
def show_video(video_path):
    if os.path.exists(video_path):
        displayVid(outVid(video_path, embed=True))
    else:
        print(f"Error: {video_path} not found!")

# Show the video
show_video("video.mp4")
